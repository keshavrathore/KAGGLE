# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import math as mt
from pylab import savefig

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))

# Keras is a deep learning library that wraps the efficient numerical libraries Theano and TensorFlow.
# It provides a clean and simple API that allows you to define and evaluate deep learning models in just a few lines of code.from keras.models import Sequential, load_model
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping, ModelCheckpoint

# define custom R2 metrics for Keras backend
from keras import backend as K

# model evaluation
from sklearn.model_selection import KFold, train_test_split 
from sklearn.metrics import r2_score, mean_squared_error

# define path to save model
model_path = 'keras_model.h5'

# fix random seed for reproducibility
seed = 42
np.random.seed(seed)

# Read datasets
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# save IDs for submission
id_test = test['ID'].copy()

###########################
# DATA PREPARATION
###########################

# glue datasets together
total = pd.concat([train, test], axis=0)
print('initial shape: {}'.format(total.shape))

# binary indexes for train/test set split
is_train = ~total.y.isnull()

# find all categorical features
cf = total.select_dtypes(include=['object']).columns

# make one-hot-encoding convenient way - pandas.get_dummies(df) function
dummies = pd.get_dummies(
    total[cf],
    drop_first=False # you can set it = True to ommit multicollinearity (crucial for linear models)
)

print('oh-encoded shape: {}'.format(dummies.shape))

# get rid of old columns and append them encoded
total = pd.concat(
    [
        total.drop(cf, axis=1), # drop old
        dummies # append them one-hot-encoded
    ],
    axis=1 # column-wise
)

print('appended-encoded shape: {}'.format(total.shape))

# recreate train/test again, now with dropped ID column
train, test = total[is_train].drop(['ID'], axis=1), total[~is_train].drop(['ID', 'y'], axis=1)

# drop redundant objects
del total

# check shape
print('\nTrain shape: {}\nTest shape: {}'.format(train.shape, test.shape))

#########################################################################################################################################
# GENERATE MODEL
# The Keras wrappers require a function as an argument. 
# This function that we must define is responsible for creating the neural network model to be evaluated.
# Below we define the function to create the baseline model to be evaluated. 
# The network uses good practices such as the rectifier activation function for the hidden layer. 
# No activation function is used for the output layer because it is a regression problem and we are interested in predicting numerical 
# values directly without transform.# The efficient ADAM optimization algorithm is used and a mean squared error loss function is optimized. 
# This will be the same metric that we will use to evaluate the performance of the model. 
# It is a desirable metric because by taking the square root gives us an error value we can directly understand in the context of the problem.
##########################################################################################################################################

def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true - y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )
    
# Base model architecture definition.
# Dropout is a technique where randomly selected neurons are ignored during training. 
# They are dropped-out randomly. This means that their contribution to the activation.
# of downstream neurons is temporally removed on the forward pass and any weight updates are
# not applied to the neuron on the backward pass.
# More info on Dropout here http://machinelearningmastery.com/dropout-regularization-deep-learning-models-keras/
# BatchNormalization, Normalize the activations of the previous layer at each batch, i.e. applies a transformation 
# that maintains the mean activation close to 0 and the activation standard deviation close to 1.
def model():
    model = Sequential()
    #input layer
    model.add(Dense(input_dims, input_dim=input_dims))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.4))
    # hidden layers
    model.add(Dense(input_dims))
    model.add(BatchNormalization())
    model.add(Activation(act_func))
    model.add(Dropout(0.4))
    
    model.add(Dense(input_dims//2))
    model.add(BatchNormalization())
    model.add(Activation(act_func))
    model.add(Dropout(0.4))
    
    model.add(Dense(input_dims//4, activation=act_func))
    
    # output layer (y_pred)
    model.add(Dense(1, activation='linear'))
    
    # compile this model
    model.compile(loss='mean_squared_error', # one may use 'mean_absolute_error' as alternative
                  optimizer='adam',
                  metrics=[r2_keras] # you can add several if needed
                 )
    # Visualize NN architecture
    print(model.summary())
    return model

#activation functions for hidden layers
act_func = 'tanh' # could be 'relu', 'sigmoid', ...tanh

# initialize input dimension

input_dims = train.shape[1]-1
# input_dims = train_reduced.shape[1]

# initialize estimator, wrap model in KerasRegressor
estimator = KerasRegressor(
    build_fn=model, 
    nb_epoch=300, 
    batch_size=30,
    verbose=1
)

# X, y preparation
X, y = train.drop('y', axis=1).copy().values, train.y.values
X_test = test.values
print('\nTrain shape No Feature Selection: {}\nTest shape No Feature Selection: {}'.format(X.shape, X_test.shape))

###############
# K-FOLD
###############
"""Return the sample arithmetic mean of data."""
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)
"""Return sum of square deviations of sequence data."""    
def sum_of_square_deviation(numbers,mean):
    return float(1/len(numbers) * sum((x - mean)** 2 for x in numbers))    
  
n_splits = 4
kf = KFold(n_splits=n_splits, random_state=seed, shuffle=True)
kf.get_n_splits(X)

mse_scores = list()
r2_scores = list()

for fold, (train_index, test_index) in enumerate(kf.split(X)):
    
    print("TRAIN:", train_index, "TEST:", test_index)
    X_tr, X_val = X[train_index], X[test_index]
    y_tr, y_val = y[train_index], y[test_index]

    # prepare callbacks
    callbacks = [
        EarlyStopping(
            monitor='val_r2_keras', 
            patience=20,
            mode='max',
            verbose=1)
    ]
    # fit estimator
    history = estimator.fit(
        X_tr, 
        y_tr, 
        epochs=500,
        validation_data=(X_val, y_val),
        verbose=2,
        callbacks=callbacks,
        shuffle=True
    )
    
    pred = estimator.predict(X_val)
    
    mse = mean_squared_error(y_val, estimator.predict(X_val))**0.5
    r2 = r2_score(y_val, estimator.predict(X_val))
    mse_scores.append(mse)
    r2_scores.append(r2)
    
    print('Fold %d: Mean Squared Error %f'%(fold, mse))
    print('Fold %d: R^2 %f'%(fold, r2))

    #save results
    pred = estimator.predict(X_test)
    output = pd.DataFrame({'id': id_test, 'y': pred})
    output.to_csv(str(r2)+'_submission_keras.csv', index=False)

mean_mse = mean(mse_scores)
mean_r2 = mean(r2_scores)

standard_deviation_mse = mt.sqrt(sum_of_square_deviation(mse_scores,mean_mse))
standard_deviation_r2 = mt.sqrt(sum_of_square_deviation(r2_scores,mean_r2))

print('=====================')
print( 'Mean Squared Error %f'%mean_mse)
print('=====================')
print('=====================')
print( 'Stdev Squared Error %f'%standard_deviation_mse)
print('=====================')
print('=====================')
print( 'Mean R^2 %f'%mean_r2)
print('=====================')
print('=====================')
print( 'Stdev R^2 %f'%standard_deviation_r2)
print('=====================')

# prepare callbacks
callbacks = [
    EarlyStopping(
        monitor='val_r2_keras', 
        patience=20,
        mode='max',
        verbose=1),
    ModelCheckpoint(
        model_path, 
        monitor='val_r2_keras', 
        save_best_only=True, 
        mode='max',
        verbose=0)
]

# train/validation split
X_tr, X_val, y_tr, y_val = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    random_state=seed
)

# fit estimator
history = estimator.fit(
    X_tr, 
    y_tr, 
    epochs=500,
    validation_data=(X_val, y_val),
    verbose=2,
    callbacks=callbacks,
    shuffle=True
)

# list all data in history
print(history.history.keys())

# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model accuracy')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_accuracy.png")

# summarize history for loss
fig_loss = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_loss.savefig("model_loss.png")

# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):
    estimator = load_model(model_path, custom_objects={'r2_keras': r2_keras})

# Plot in blue color the predicted data and in green color the
# actual data to verify visually the accuracy of the model.
predicted = estimator.predict(X_val)
fig_verify = plt.figure(figsize=(100, 50))
plt.plot(predicted, color="blue")
plt.plot(y_val, color="green")
plt.title('prediction')
plt.ylabel('value')
plt.xlabel('row')
plt.legend(['predicted', 'actual data'], loc='upper left')
plt.show()
fig_verify.savefig("model_verify.png")

# check performance on train set
print('MSE train: {}'.format(mean_squared_error(y_tr, estimator.predict(X_tr))**0.5)) # mse train
print('R^2 train: {}'.format(r2_score(y_tr, estimator.predict(X_tr)))) # R^2 train

# check performance on validation set
print('MSE val: {}'.format(mean_squared_error(y_val, estimator.predict(X_val))**0.5)) # mse val
print('R^2 val: {}'.format(r2_score(y_val, estimator.predict(X_val)))) # R^2 val
pass

# predict results
res = estimator.predict(X_test).ravel()
print(res)

# create df and convert it to csv
output = pd.DataFrame({'id': id_test, 'y': res})
output.to_csv('keras-baseline.csv', index=False)
# Out:
# initial shape: (8418, 378)
# oh-encoded shape: (8418, 211)
# appended-encoded shape: (8418, 581)
#
# Train shape: (4209, 580)
# Test shape: (4209, 579)
#
# Train shape No Feature Selection: (4209, 579)
# Test shape No Feature Selection: (4209, 579)
# TRAIN: [   0    1    2 ... 4205 4206 4207] TEST: [   6    8   12 ... 4193 4198 4208]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 579)               335820
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_1 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 579)               335820
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_2 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 289)               167620
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 289)               1156
# _________________________________________________________________
# activation_3 (Activation)    (None, 289)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 289)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 144)               41760
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 145
# =================================================================
# Total params: 886,953
# Trainable params: 884,059
# Non-trainable params: 2,894
# _________________________________________________________________
# None
# Train on 3156 samples, validate on 1053 samples
# Epoch 1/500
#  - 3s - loss: 9198.5996 - r2_keras: -6.7047e+01 - val_loss: 5941.7052 - val_r2_keras: -4.5609e+01
# Epoch 2/500
#  - 2s - loss: 4887.6816 - r2_keras: -3.4837e+01 - val_loss: 3600.8752 - val_r2_keras: -2.6585e+01
# Epoch 3/500
#  - 2s - loss: 2927.6527 - r2_keras: -2.0377e+01 - val_loss: 2554.4222 - val_r2_keras: -1.7914e+01
# Epoch 4/500
#  - 3s - loss: 2123.4847 - r2_keras: -1.3717e+01 - val_loss: 1976.7447 - val_r2_keras: -1.3325e+01
# Epoch 5/500
#  - 3s - loss: 811.9931 - r2_keras: -4.7436e+00 - val_loss: 482.4346 - val_r2_keras: -2.6270e+00
# Epoch 6/500
#  - 2s - loss: 372.6128 - r2_keras: -1.5621e+00 - val_loss: 279.7346 - val_r2_keras: -1.0118e+00
# Epoch 7/500
#  - 3s - loss: 232.8003 - r2_keras: -5.5209e-01 - val_loss: 189.0325 - val_r2_keras: -3.0175e-01
# Epoch 8/500
#  - 3s - loss: 172.0396 - r2_keras: -1.0266e-01 - val_loss: 154.0833 - val_r2_keras: -2.8973e-02
# Epoch 9/500
#  - 4s - loss: 149.7357 - r2_keras: 0.0456 - val_loss: 143.4604 - val_r2_keras: 0.0576
# Epoch 10/500
#  - 3s - loss: 141.8791 - r2_keras: 0.0766 - val_loss: 139.9497 - val_r2_keras: 0.0868
# Epoch 11/500
#  - 3s - loss: 136.9050 - r2_keras: 0.1276 - val_loss: 135.7561 - val_r2_keras: 0.1229
# Epoch 12/500
#  - 3s - loss: 134.6427 - r2_keras: 0.1360 - val_loss: 126.9969 - val_r2_keras: 0.1814
# Epoch 13/500
#  - 3s - loss: 123.0944 - r2_keras: 0.1794 - val_loss: 116.3539 - val_r2_keras: 0.2387
# Epoch 14/500
#  - 3s - loss: 115.5717 - r2_keras: 0.2759 - val_loss: 107.2461 - val_r2_keras: 0.2773
# Epoch 15/500
#  - 3s - loss: 111.5543 - r2_keras: 0.3087 - val_loss: 100.3177 - val_r2_keras: 0.2970
# Epoch 16/500
#  - 3s - loss: 100.1964 - r2_keras: 0.3857 - val_loss: 89.9164 - val_r2_keras: 0.3923
# Epoch 17/500
#  - 3s - loss: 93.2961 - r2_keras: 0.4321 - val_loss: 85.4910 - val_r2_keras: 0.3952
# Epoch 18/500
#  - 4s - loss: 86.5840 - r2_keras: 0.4863 - val_loss: 83.3848 - val_r2_keras: 0.4277
# Epoch 19/500
#  - 3s - loss: 85.2466 - r2_keras: 0.4932 - val_loss: 81.1924 - val_r2_keras: 0.4183
# Epoch 20/500
#  - 3s - loss: 79.6535 - r2_keras: 0.5364 - val_loss: 78.3468 - val_r2_keras: 0.4591
# Epoch 21/500
#  - 4s - loss: 77.7917 - r2_keras: 0.5378 - val_loss: 78.3068 - val_r2_keras: 0.4612
# Epoch 22/500
#  - 3s - loss: 75.5681 - r2_keras: 0.5529 - val_loss: 77.5262 - val_r2_keras: 0.4721
# Epoch 23/500
#  - 3s - loss: 72.7012 - r2_keras: 0.5806 - val_loss: 77.3325 - val_r2_keras: 0.4745
# Epoch 24/500
#  - 3s - loss: 72.3497 - r2_keras: 0.5751 - val_loss: 76.0899 - val_r2_keras: 0.4651
# Epoch 25/500
#  - 3s - loss: 69.2275 - r2_keras: 0.5949 - val_loss: 76.1112 - val_r2_keras: 0.4521
# Epoch 26/500
#  - 3s - loss: 67.7477 - r2_keras: 0.6076 - val_loss: 75.0605 - val_r2_keras: 0.4414
# Epoch 27/500
#  - 3s - loss: 67.9688 - r2_keras: 0.5983 - val_loss: 75.7649 - val_r2_keras: 0.4376
# Epoch 28/500
#  - 3s - loss: 66.8127 - r2_keras: 0.5811 - val_loss: 75.3812 - val_r2_keras: 0.4531
# Epoch 29/500
#  - 3s - loss: 66.6199 - r2_keras: 0.5592 - val_loss: 77.5688 - val_r2_keras: 0.4429
# Epoch 30/500
#  - 3s - loss: 64.9348 - r2_keras: 0.6254 - val_loss: 75.3461 - val_r2_keras: 0.4653
# Epoch 31/500
#  - 3s - loss: 63.3632 - r2_keras: 0.6309 - val_loss: 74.7401 - val_r2_keras: 0.4518
# Epoch 32/500
#  - 3s - loss: 63.6652 - r2_keras: 0.5874 - val_loss: 74.2873 - val_r2_keras: 0.4262
# Epoch 33/500
#  - 3s - loss: 64.1119 - r2_keras: 0.5618 - val_loss: 76.4511 - val_r2_keras: 0.4147
# Epoch 34/500
#  - 3s - loss: 64.5262 - r2_keras: 0.6199 - val_loss: 75.1215 - val_r2_keras: 0.4101
# Epoch 35/500
#  - 3s - loss: 62.1027 - r2_keras: 0.6371 - val_loss: 75.5745 - val_r2_keras: 0.4318
# Epoch 36/500
#  - 3s - loss: 61.1522 - r2_keras: 0.6285 - val_loss: 75.1938 - val_r2_keras: 0.4490
# Epoch 37/500
#  - 4s - loss: 61.9691 - r2_keras: 0.6327 - val_loss: 74.8687 - val_r2_keras: 0.4278
# Epoch 38/500
#  - 3s - loss: 63.0851 - r2_keras: 0.6290 - val_loss: 74.9789 - val_r2_keras: 0.4502
# Epoch 39/500
#  - 3s - loss: 61.9991 - r2_keras: 0.6134 - val_loss: 76.9125 - val_r2_keras: 0.4339
# Epoch 40/500
#  - 3s - loss: 62.3173 - r2_keras: 0.6369 - val_loss: 80.1247 - val_r2_keras: 0.4200
# Epoch 41/500
#  - 2s - loss: 59.2840 - r2_keras: 0.6594 - val_loss: 77.1058 - val_r2_keras: 0.4540
# Epoch 42/500
#  - 2s - loss: 60.6201 - r2_keras: 0.6412 - val_loss: 76.6744 - val_r2_keras: 0.4548
# Epoch 43/500
#  - 3s - loss: 60.2800 - r2_keras: 0.6425 - val_loss: 77.9176 - val_r2_keras: 0.4240
# Epoch 00043: early stopping
# 1053/1053 [==============================] - 0s 302us/step
# 1053/1053 [==============================] - 0s 145us/step
# 1053/1053 [==============================] - 0s 151us/step
# Fold 0: Mean Squared Error 8.827097
# Fold 0: R^2 0.509753
# 4209/4209 [==============================] - 1s 157us/step
# TRAIN: [   1    2    3 ... 4204 4206 4208] TEST: [   0    7   22 ... 4200 4205 4207]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 579)               335820
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_4 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 579)               335820
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_5 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 289)               167620
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 289)               1156
# _________________________________________________________________
# activation_6 (Activation)    (None, 289)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 289)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 144)               41760
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 145
# =================================================================
# Total params: 886,953
# Trainable params: 884,059
# Non-trainable params: 2,894
# _________________________________________________________________
# None
# Train on 3157 samples, validate on 1052 samples
# Epoch 1/500
#  - 3s - loss: 9159.9659 - r2_keras: -6.9770e+01 - val_loss: 5859.2588 - val_r2_keras: -4.0482e+01
# Epoch 2/500
#  - 3s - loss: 4848.3768 - r2_keras: -3.5238e+01 - val_loss: 3479.4997 - val_r2_keras: -2.3386e+01
# Epoch 3/500
#  - 3s - loss: 2922.4743 - r2_keras: -2.0379e+01 - val_loss: 1624.6008 - val_r2_keras: -1.0081e+01
# Epoch 4/500
#  - 3s - loss: 1161.3017 - r2_keras: -7.4224e+00 - val_loss: 834.7955 - val_r2_keras: -4.4919e+00
# Epoch 5/500
#  - 3s - loss: 577.6449 - r2_keras: -3.1473e+00 - val_loss: 459.2230 - val_r2_keras: -1.8696e+00
# Epoch 6/500
#  - 3s - loss: 321.1430 - r2_keras: -1.2572e+00 - val_loss: 288.3936 - val_r2_keras: -7.0345e-01
# Epoch 7/500
#  - 2s - loss: 211.7817 - r2_keras: -4.5388e-01 - val_loss: 219.4582 - val_r2_keras: -2.5300e-01
# Epoch 8/500
#  - 2s - loss: 168.4923 - r2_keras: -1.4619e-01 - val_loss: 187.3413 - val_r2_keras: -5.1032e-02
# Epoch 9/500
#  - 3s - loss: 144.7959 - r2_keras: 0.0123 - val_loss: 169.8616 - val_r2_keras: 0.0557
# Epoch 10/500
#  - 3s - loss: 132.6347 - r2_keras: 0.0980 - val_loss: 163.6734 - val_r2_keras: 0.0870
# Epoch 11/500
#  - 3s - loss: 129.9329 - r2_keras: 0.1205 - val_loss: 162.0242 - val_r2_keras: 0.0903
# Epoch 12/500
#  - 3s - loss: 129.9709 - r2_keras: 0.1090 - val_loss: 161.3735 - val_r2_keras: 0.0918
# Epoch 13/500
#  - 2s - loss: 125.4698 - r2_keras: 0.1538 - val_loss: 150.7893 - val_r2_keras: 0.1788
# Epoch 14/500
#  - 3s - loss: 114.7511 - r2_keras: 0.2306 - val_loss: 142.0600 - val_r2_keras: 0.2492
# Epoch 15/500
#  - 3s - loss: 103.5029 - r2_keras: 0.3027 - val_loss: 129.0089 - val_r2_keras: 0.3417
# Epoch 16/500
#  - 3s - loss: 92.0316 - r2_keras: 0.3832 - val_loss: 118.6464 - val_r2_keras: 0.4219
# Epoch 17/500
#  - 3s - loss: 83.6630 - r2_keras: 0.4521 - val_loss: 110.6080 - val_r2_keras: 0.4681
# Epoch 18/500
#  - 2s - loss: 76.6861 - r2_keras: 0.3444 - val_loss: 107.7755 - val_r2_keras: 0.4825
# Epoch 19/500
#  - 2s - loss: 73.1661 - r2_keras: 0.5197 - val_loss: 106.0340 - val_r2_keras: 0.4908
# Epoch 20/500
#  - 2s - loss: 70.9934 - r2_keras: 0.5407 - val_loss: 104.9122 - val_r2_keras: 0.5050
# Epoch 21/500
#  - 3s - loss: 69.7804 - r2_keras: 0.5473 - val_loss: 103.6987 - val_r2_keras: 0.5123
# Epoch 22/500
#  - 3s - loss: 67.2553 - r2_keras: 0.5579 - val_loss: 102.7595 - val_r2_keras: 0.5172
# Epoch 23/500
#  - 3s - loss: 65.0268 - r2_keras: 0.5654 - val_loss: 101.6446 - val_r2_keras: 0.5228
# Epoch 24/500
#  - 3s - loss: 65.2534 - r2_keras: 0.5689 - val_loss: 101.4532 - val_r2_keras: 0.5269
# Epoch 25/500
#  - 3s - loss: 63.2218 - r2_keras: 0.5824 - val_loss: 100.3932 - val_r2_keras: 0.5337
# Epoch 26/500
#  - 3s - loss: 60.5854 - r2_keras: 0.6042 - val_loss: 99.0910 - val_r2_keras: 0.5435
# Epoch 27/500
#  - 3s - loss: 60.6605 - r2_keras: 0.5735 - val_loss: 102.2291 - val_r2_keras: 0.5170
# Epoch 28/500
#  - 3s - loss: 59.0880 - r2_keras: 0.5561 - val_loss: 100.4142 - val_r2_keras: 0.5365
# Epoch 29/500
#  - 3s - loss: 59.6239 - r2_keras: 0.6114 - val_loss: 97.4967 - val_r2_keras: 0.5534
# Epoch 30/500
#  - 2s - loss: 58.1667 - r2_keras: 0.6213 - val_loss: 99.4233 - val_r2_keras: 0.5410
# Epoch 31/500
#  - 2s - loss: 57.3513 - r2_keras: 0.6055 - val_loss: 97.5140 - val_r2_keras: 0.5551
# Epoch 32/500
#  - 2s - loss: 58.7248 - r2_keras: 0.6196 - val_loss: 98.8787 - val_r2_keras: 0.5472
# Epoch 33/500
#  - 3s - loss: 57.2268 - r2_keras: 0.6138 - val_loss: 100.4115 - val_r2_keras: 0.5339
# Epoch 34/500
#  - 3s - loss: 57.0943 - r2_keras: 0.6295 - val_loss: 99.7735 - val_r2_keras: 0.5362
# Epoch 35/500
#  - 3s - loss: 54.5951 - r2_keras: 0.6452 - val_loss: 97.6350 - val_r2_keras: 0.5537
# Epoch 36/500
#  - 4s - loss: 55.3826 - r2_keras: 0.6277 - val_loss: 101.1266 - val_r2_keras: 0.5318
# Epoch 37/500
#  - 4s - loss: 54.5293 - r2_keras: 0.6349 - val_loss: 98.2665 - val_r2_keras: 0.5454
# Epoch 38/500
#  - 3s - loss: 55.6137 - r2_keras: 0.6349 - val_loss: 99.1799 - val_r2_keras: 0.5407
# Epoch 39/500
#  - 3s - loss: 52.8259 - r2_keras: 0.6547 - val_loss: 98.3966 - val_r2_keras: 0.5498
# Epoch 40/500
#  - 3s - loss: 53.4323 - r2_keras: 0.6442 - val_loss: 102.0653 - val_r2_keras: 0.5219
# Epoch 41/500
#  - 3s - loss: 53.3468 - r2_keras: 0.6418 - val_loss: 100.0000 - val_r2_keras: 0.5375
# Epoch 42/500
#  - 3s - loss: 52.6773 - r2_keras: 0.6498 - val_loss: 99.6781 - val_r2_keras: 0.5413
# Epoch 43/500
#  - 3s - loss: 52.0934 - r2_keras: 0.6593 - val_loss: 99.2532 - val_r2_keras: 0.5388
# Epoch 44/500
#  - 3s - loss: 50.5934 - r2_keras: 0.6628 - val_loss: 99.4352 - val_r2_keras: 0.5421
# Epoch 45/500
#  - 3s - loss: 52.7820 - r2_keras: 0.6583 - val_loss: 99.3043 - val_r2_keras: 0.5425
# Epoch 46/500
#  - 3s - loss: 51.0237 - r2_keras: 0.6658 - val_loss: 98.9747 - val_r2_keras: 0.5471
# Epoch 47/500
#  - 3s - loss: 50.7899 - r2_keras: 0.6604 - val_loss: 98.7170 - val_r2_keras: 0.5451
# Epoch 48/500
#  - 3s - loss: 49.2295 - r2_keras: 0.6716 - val_loss: 97.9803 - val_r2_keras: 0.5496
# Epoch 49/500
#  - 3s - loss: 48.6031 - r2_keras: 0.6780 - val_loss: 99.7335 - val_r2_keras: 0.5425
# Epoch 50/500
#  - 3s - loss: 49.0432 - r2_keras: 0.6777 - val_loss: 102.2251 - val_r2_keras: 0.5196
# Epoch 51/500
#  - 3s - loss: 47.8603 - r2_keras: 0.6873 - val_loss: 99.6245 - val_r2_keras: 0.5448
# Epoch 00051: early stopping
# 1052/1052 [==============================] - 0s 353us/step
# 1052/1052 [==============================] - 0s 212us/step
# 1052/1052 [==============================] - 0s 195us/step
# Fold 1: Mean Squared Error 9.981205
# Fold 1: R^2 0.457581
# 4209/4209 [==============================] - 1s 215us/step
# TRAIN: [   0    1    4 ... 4205 4207 4208] TEST: [   2    3    5 ... 4192 4201 4206]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_7 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 579)               2316
# _________________________________________________________________
# activation_8 (Activation)    (None, 579)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 579)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 289)               167620
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 289)               1156
# _________________________________________________________________
# activation_9 (Activation)    (None, 289)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 289)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 144)               41760
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 145
# =================================================================
# Total params: 886,953
# Trainable params: 884,059
# Non-trainable params: 2,894
# _________________________________________________________________
# None
# Train on 3157 samples, validate on 1052 samples
# Epoch 1/500
#  - 3s - loss: 9156.5664 - r2_keras: -6.5948e+01 - val_loss: 6803.1606 - val_r2_keras: -2.6014e+02
# Epoch 2/500
#  - 3s - loss: 6555.8807 - r2_keras: -4.7972e+01 - val_loss: 5744.4355 - val_r2_keras: -1.7286e+02
# Epoch 3/500
#  - 4s - loss: 4675.7088 - r2_keras: -3.2638e+01 - val_loss: 1975.6938 - val_r2_keras: -9.3265e+01
# Epoch 4/500
#  - 4s - loss: 1265.0619 - r2_keras: -7.9704e+00 - val_loss: 758.4105 - val_r2_keras: -3.9307e+01
# Epoch 5/500
#  - 3s - loss: 556.6224 - r2_keras: -2.7822e+00 - val_loss: 357.3881 - val_r2_keras: -1.7812e+01
# Epoch 6/500
#  - 3s - loss: 292.7670 - r2_keras: -9.0427e-01 - val_loss: 210.7936 - val_r2_keras: -8.5572e+00
# Epoch 7/500
#  - 4s - loss: 195.3760 - r2_keras: -2.3903e-01 - val_loss: 149.4279 - val_r2_keras: -4.4698e+00
# Epoch 8/500
#  - 3s - loss: 158.9280 - r2_keras: 0.0029 - val_loss: 132.5793 - val_r2_keras: -2.6284e+00
# Epoch 9/500
#  - 3s - loss: 147.6494 - r2_keras: 0.0862 - val_loss: 125.3170 - val_r2_keras: -1.7852e+00
# Epoch 10/500
#  - 3s - loss: 142.5934 - r2_keras: 0.1081 - val_loss: 122.0990 - val_r2_keras: -1.4029e+00
# Epoch 11/500
#  - 3s - loss: 139.5990 - r2_keras: 0.1216 - val_loss: 118.5881 - val_r2_keras: -1.1126e+00
# Epoch 12/500
#  - 3s - loss: 136.6346 - r2_keras: 0.1361 - val_loss: 116.6494 - val_r2_keras: -9.1282e-01
# Epoch 13/500
#  - 3s - loss: 133.0261 - r2_keras: 0.1749 - val_loss: 111.6239 - val_r2_keras: -6.8125e-01
# Epoch 14/500
#  - 3s - loss: 129.1150 - r2_keras: 0.2000 - val_loss: 105.2554 - val_r2_keras: -3.8425e-01
# Epoch 15/500
#  - 3s - loss: 122.0299 - r2_keras: 0.2499 - val_loss: 98.2447 - val_r2_keras: -1.0547e-01
# Epoch 16/500
#  - 3s - loss: 113.8879 - r2_keras: 0.3109 - val_loss: 89.1383 - val_r2_keras: 0.1560
# Epoch 17/500
#  - 3s - loss: 104.5973 - r2_keras: 0.3591 - val_loss: 79.2350 - val_r2_keras: 0.3572
# Epoch 18/500
#  - 3s - loss: 97.1767 - r2_keras: 0.4245 - val_loss: 76.1272 - val_r2_keras: 0.4498
# Epoch 19/500
#  - 3s - loss: 89.8957 - r2_keras: 0.4747 - val_loss: 72.0565 - val_r2_keras: 0.5068
# Epoch 20/500
#  - 3s - loss: 84.5803 - r2_keras: 0.5086 - val_loss: 69.0836 - val_r2_keras: 0.5147
# Epoch 21/500
#  - 3s - loss: 82.0673 - r2_keras: 0.5262 - val_loss: 66.6030 - val_r2_keras: 0.4834
# Epoch 22/500
#  - 3s - loss: 78.6944 - r2_keras: 0.5393 - val_loss: 63.6963 - val_r2_keras: 0.4020
# Epoch 23/500
#  - 3s - loss: 76.4143 - r2_keras: 0.5573 - val_loss: 62.7808 - val_r2_keras: 0.3255
# Epoch 24/500
#  - 3s - loss: 77.4844 - r2_keras: 0.5576 - val_loss: 62.4738 - val_r2_keras: 0.2389
# Epoch 25/500
#  - 3s - loss: 74.7420 - r2_keras: 0.5586 - val_loss: 62.0488 - val_r2_keras: 0.1621
# Epoch 26/500
#  - 4s - loss: 72.8729 - r2_keras: 0.5818 - val_loss: 61.8893 - val_r2_keras: 0.0818
# Epoch 27/500
#  - 4s - loss: 71.3708 - r2_keras: 0.5893 - val_loss: 63.7003 - val_r2_keras: -1.2042e-02
# Epoch 28/500
#  - 4s - loss: 70.7307 - r2_keras: 0.5867 - val_loss: 61.3557 - val_r2_keras: -2.1598e-02
# Epoch 29/500
#  - 4s - loss: 70.2012 - r2_keras: 0.5933 - val_loss: 61.7710 - val_r2_keras: -1.3722e-01
# Epoch 30/500
#  - 4s - loss: 69.1668 - r2_keras: 0.6032 - val_loss: 60.4467 - val_r2_keras: -1.4958e-01
# Epoch 31/500
#  - 4s - loss: 70.2007 - r2_keras: 0.5924 - val_loss: 62.4863 - val_r2_keras: -3.4325e-01
# Epoch 32/500
#  - 3s - loss: 67.2488 - r2_keras: 0.6068 - val_loss: 62.4442 - val_r2_keras: -3.2970e-01
# Epoch 33/500
#  - 3s - loss: 67.5012 - r2_keras: 0.6137 - val_loss: 61.2749 - val_r2_keras: -2.9157e-01
# Epoch 34/500
#  - 3s - loss: 68.6523 - r2_keras: 0.5998 - val_loss: 60.6810 - val_r2_keras: -4.0633e-01
# Epoch 35/500
#  - 3s - loss: 68.0434 - r2_keras: 0.6070 - val_loss: 60.9315 - val_r2_keras: -1.7256e-01
# Epoch 36/500
#  - 3s - loss: 66.3292 - r2_keras: 0.6146 - val_loss: 61.1011 - val_r2_keras: -1.4959e-01
# Epoch 37/500
#  - 3s - loss: 64.5689 - r2_keras: 0.6238 - val_loss: 61.2929 - val_r2_keras: 0.0417
# Epoch 38/500
#  - 3s - loss: 64.0697 - r2_keras: 0.6244 - val_loss: 61.2016 - val_r2_keras: -2.2404e-02
# Epoch 39/500
#  - 3s - loss: 65.8183 - r2_keras: 0.6198 - val_loss: 62.1020 - val_r2_keras: 0.1202
# Epoch 40/500
#  - 3s - loss: 62.2866 - r2_keras: 0.6181 - val_loss: 61.8896 - val_r2_keras: -3.9311e-01
# Epoch 00040: early stopping
# 1052/1052 [==============================] - 0s 378us/step
# 1052/1052 [==============================] - 0s 209us/step
# 1052/1052 [==============================] - 0s 209us/step
# Fold 2: Mean Squared Error 7.866994
# Fold 2: R^2 0.586736
# 4209/4209 [==============================] - 1s 225us/step
# TRAIN: [   0    2    3 ... 4206 4207 4208] TEST: [   1    4    9 ... 4202 4203 4204]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 579)               2316
# _________________________________________________________________
# activation_10 (Activation)   (None, 579)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 579)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 579)               2316
# _________________________________________________________________
# activation_11 (Activation)   (None, 579)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 579)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 289)               167620
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 289)               1156
# _________________________________________________________________
# activation_12 (Activation)   (None, 289)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 289)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 144)               41760
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 145
# =================================================================
# Total params: 886,953
# Trainable params: 884,059
# Non-trainable params: 2,894
# _________________________________________________________________
# None
# Train on 3157 samples, validate on 1052 samples
# Epoch 1/500
#  - 4s - loss: 9137.3166 - r2_keras: -6.5055e+01 - val_loss: 5902.0662 - val_r2_keras: -4.3186e+01
# Epoch 2/500
#  - 3s - loss: 4668.8267 - r2_keras: -3.2492e+01 - val_loss: 2679.5189 - val_r2_keras: -1.8942e+01
# Epoch 3/500
#  - 3s - loss: 1994.6466 - r2_keras: -1.3322e+01 - val_loss: 1325.8327 - val_r2_keras: -8.7423e+00
# Epoch 4/500
#  - 3s - loss: 1020.6443 - r2_keras: -6.2799e+00 - val_loss: 679.1906 - val_r2_keras: -3.8967e+00
# Epoch 5/500
#  - 3s - loss: 547.8045 - r2_keras: -2.7925e+00 - val_loss: 367.5834 - val_r2_keras: -1.5836e+00
# Epoch 6/500
#  - 3s - loss: 317.1367 - r2_keras: -1.0886e+00 - val_loss: 228.7157 - val_r2_keras: -5.7037e-01
# Epoch 7/500
#  - 3s - loss: 215.9321 - r2_keras: -3.7206e-01 - val_loss: 172.4919 - val_r2_keras: -1.7329e-01
# Epoch 8/500
#  - 4s - loss: 171.7485 - r2_keras: -7.6786e-02 - val_loss: 137.0055 - val_r2_keras: 0.0690
# Epoch 9/500
#  - 3s - loss: 149.0784 - r2_keras: 0.0580 - val_loss: 127.5849 - val_r2_keras: 0.1253
# Epoch 10/500
#  - 3s - loss: 140.4927 - r2_keras: 0.1313 - val_loss: 122.4465 - val_r2_keras: 0.1551
# Epoch 11/500
#  - 3s - loss: 136.6978 - r2_keras: 0.1498 - val_loss: 119.2116 - val_r2_keras: 0.1719
# Epoch 12/500
#  - 3s - loss: 135.0799 - r2_keras: 0.1194 - val_loss: 116.7203 - val_r2_keras: 0.1862
# Epoch 13/500
#  - 3s - loss: 147.9283 - r2_keras: 0.0667 - val_loss: 117.1950 - val_r2_keras: 0.1799
# Epoch 14/500
#  - 3s - loss: 130.8742 - r2_keras: 0.1677 - val_loss: 113.4884 - val_r2_keras: 0.2066
# Epoch 15/500
#  - 3s - loss: 122.2213 - r2_keras: 0.2566 - val_loss: 104.9250 - val_r2_keras: 0.2688
# Epoch 16/500
#  - 3s - loss: 114.2099 - r2_keras: 0.3109 - val_loss: 95.9160 - val_r2_keras: 0.3272
# Epoch 17/500
#  - 3s - loss: 104.8703 - r2_keras: 0.3547 - val_loss: 82.5990 - val_r2_keras: 0.4441
# Epoch 18/500
#  - 3s - loss: 95.3520 - r2_keras: 0.4414 - val_loss: 79.1583 - val_r2_keras: 0.4707
# Epoch 19/500
#  - 3s - loss: 89.4530 - r2_keras: 0.4789 - val_loss: 75.2938 - val_r2_keras: 0.4972
# Epoch 20/500
#  - 3s - loss: 88.3755 - r2_keras: 0.4866 - val_loss: 72.8784 - val_r2_keras: 0.5106
# Epoch 21/500
#  - 3s - loss: 84.0390 - r2_keras: 0.5049 - val_loss: 71.8314 - val_r2_keras: 0.5158
# Epoch 22/500
#  - 3s - loss: 81.2882 - r2_keras: 0.5294 - val_loss: 71.0913 - val_r2_keras: 0.5254
# Epoch 23/500
#  - 3s - loss: 80.5031 - r2_keras: 0.5307 - val_loss: 69.1138 - val_r2_keras: 0.5382
# Epoch 24/500
#  - 3s - loss: 78.8018 - r2_keras: 0.5470 - val_loss: 67.2219 - val_r2_keras: 0.5489
# Epoch 25/500
#  - 3s - loss: 80.8659 - r2_keras: 0.5090 - val_loss: 65.9874 - val_r2_keras: 0.5603
# Epoch 26/500
#  - 3s - loss: 75.2306 - r2_keras: 0.5682 - val_loss: 65.9484 - val_r2_keras: 0.5563
# Epoch 27/500
#  - 3s - loss: 72.4264 - r2_keras: 0.5776 - val_loss: 64.3568 - val_r2_keras: 0.5693
# Epoch 28/500
#  - 3s - loss: 71.6042 - r2_keras: 0.5867 - val_loss: 62.8755 - val_r2_keras: 0.5784
# Epoch 29/500
#  - 3s - loss: 69.6086 - r2_keras: 0.5971 - val_loss: 65.0664 - val_r2_keras: 0.5615
# Epoch 30/500
#  - 3s - loss: 67.8371 - r2_keras: 0.6035 - val_loss: 61.3366 - val_r2_keras: 0.5885
# Epoch 31/500
#  - 3s - loss: 68.2479 - r2_keras: 0.6072 - val_loss: 63.2399 - val_r2_keras: 0.5741
# Epoch 32/500
#  - 3s - loss: 68.7738 - r2_keras: 0.6070 - val_loss: 62.8342 - val_r2_keras: 0.5745
# Epoch 33/500
#  - 3s - loss: 70.0647 - r2_keras: 0.6032 - val_loss: 65.4038 - val_r2_keras: 0.5541
# Epoch 34/500
#  - 3s - loss: 67.5076 - r2_keras: 0.6115 - val_loss: 63.8406 - val_r2_keras: 0.5669
# Epoch 35/500
#  - 3s - loss: 68.1054 - r2_keras: 0.6014 - val_loss: 68.5060 - val_r2_keras: 0.5375
# Epoch 36/500
#  - 3s - loss: 67.1322 - r2_keras: 0.6216 - val_loss: 63.6332 - val_r2_keras: 0.5694
# Epoch 37/500
#  - 3s - loss: 65.2269 - r2_keras: 0.6238 - val_loss: 66.2249 - val_r2_keras: 0.5545
# Epoch 38/500
#  - 3s - loss: 63.0824 - r2_keras: 0.6355 - val_loss: 62.0891 - val_r2_keras: 0.5768
# Epoch 39/500
#  - 3s - loss: 64.3739 - r2_keras: 0.6264 - val_loss: 62.6610 - val_r2_keras: 0.5709
# Epoch 40/500
#  - 3s - loss: 62.2312 - r2_keras: 0.6140 - val_loss: 68.3110 - val_r2_keras: 0.5283
# Epoch 41/500
#  - 3s - loss: 63.5551 - r2_keras: 0.6363 - val_loss: 64.5219 - val_r2_keras: 0.5647
# Epoch 42/500
#  - 3s - loss: 61.2679 - r2_keras: 0.6540 - val_loss: 62.0731 - val_r2_keras: 0.5830
# Epoch 43/500
#  - 3s - loss: 61.1415 - r2_keras: 0.6509 - val_loss: 65.3082 - val_r2_keras: 0.5538
# Epoch 44/500
#  - 3s - loss: 61.7920 - r2_keras: 0.6409 - val_loss: 62.7713 - val_r2_keras: 0.5738
# Epoch 45/500
#  - 3s - loss: 60.2242 - r2_keras: 0.6485 - val_loss: 62.7680 - val_r2_keras: 0.5793
# Epoch 46/500
#  - 3s - loss: 61.1800 - r2_keras: 0.6504 - val_loss: 66.1519 - val_r2_keras: 0.5526
# Epoch 47/500
#  - 3s - loss: 58.2576 - r2_keras: 0.6658 - val_loss: 62.5834 - val_r2_keras: 0.5819
# Epoch 48/500
#  - 3s - loss: 59.0784 - r2_keras: 0.6544 - val_loss: 65.3205 - val_r2_keras: 0.5596
# Epoch 49/500
#  - 3s - loss: 58.0134 - r2_keras: 0.6594 - val_loss: 64.6042 - val_r2_keras: 0.5736
# Epoch 50/500
#  - 3s - loss: 56.9939 - r2_keras: 0.6750 - val_loss: 62.2298 - val_r2_keras: 0.5842
# Epoch 00050: early stopping
# 1052/1052 [==============================] - 0s 332us/step
# 1052/1052 [==============================] - 0s 174us/step
# 1052/1052 [==============================] - ETA:  - 0s 225us/step
# Fold 3: Mean Squared Error 7.888589
# Fold 3: R^2 0.585842
# 4209/4209 [==============================] - 1s 202us/step
# =====================
# Mean Squared Error 8.640971
# =====================
# =====================
# Stdev Squared Error 0.865446
# =====================
# =====================
# Mean R^2 0.534978
# =====================
# =====================
# Stdev R^2 0.054527
# =====================
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 579)               2316
# _________________________________________________________________
# activation_13 (Activation)   (None, 579)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 579)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 579)               2316
# _________________________________________________________________
# activation_14 (Activation)   (None, 579)               0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 579)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 289)               167620
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 289)               1156
# _________________________________________________________________
# activation_15 (Activation)   (None, 289)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 289)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 144)               41760
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 145
# =================================================================
# Total params: 886,953
# Trainable params: 884,059
# Non-trainable params: 2,894
# _________________________________________________________________
# None
# Train on 3367 samples, validate on 842 samples
# Epoch 1/500
#  - 5s - loss: 9073.1584 - r2_keras: -6.6388e+01 - val_loss: 5566.9769 - val_r2_keras: -3.9267e+01
# Epoch 2/500
#  - 3s - loss: 4485.7140 - r2_keras: -3.1990e+01 - val_loss: 3308.7311 - val_r2_keras: -2.2506e+01
# Epoch 3/500
#  - 3s - loss: 1956.7155 - r2_keras: -1.2932e+01 - val_loss: 1229.1448 - val_r2_keras: -7.7860e+00
# Epoch 4/500
#  - 3s - loss: 901.5361 - r2_keras: -5.5031e+00 - val_loss: 603.9151 - val_r2_keras: -3.2329e+00
# Epoch 5/500
#  - 3s - loss: 462.0593 - r2_keras: -2.1783e+00 - val_loss: 325.2009 - val_r2_keras: -1.2190e+00
# Epoch 6/500
#  - 3s - loss: 269.2328 - r2_keras: -8.0108e-01 - val_loss: 210.1471 - val_r2_keras: -4.0014e-01
# Epoch 7/500
#  - 3s - loss: 189.8321 - r2_keras: -2.3476e-01 - val_loss: 156.8786 - val_r2_keras: -3.4553e-02
# Epoch 8/500
#  - 3s - loss: 156.4804 - r2_keras: 0.0045 - val_loss: 140.1277 - val_r2_keras: 0.0740
# Epoch 9/500
#  - 3s - loss: 142.7309 - r2_keras: 0.0956 - val_loss: 132.1018 - val_r2_keras: 0.1235
# Epoch 10/500
#  - 3s - loss: 139.0184 - r2_keras: 0.1141 - val_loss: 127.6180 - val_r2_keras: 0.1517
# Epoch 11/500
#  - 3s - loss: 133.2814 - r2_keras: 0.1492 - val_loss: 122.4953 - val_r2_keras: 0.1869
# Epoch 12/500
#  - 3s - loss: 125.9807 - r2_keras: 0.2200 - val_loss: 115.3502 - val_r2_keras: 0.2370
# Epoch 13/500
#  - 3s - loss: 119.0290 - r2_keras: 0.2510 - val_loss: 102.9569 - val_r2_keras: 0.3375
# Epoch 14/500
#  - 3s - loss: 110.6792 - r2_keras: 0.3199 - val_loss: 90.4501 - val_r2_keras: 0.4244
# Epoch 15/500
#  - 3s - loss: 97.6102 - r2_keras: 0.4082 - val_loss: 81.2473 - val_r2_keras: 0.4883
# Epoch 16/500
#  - 3s - loss: 90.3183 - r2_keras: 0.4678 - val_loss: 75.9833 - val_r2_keras: 0.5239
# Epoch 17/500
#  - 3s - loss: 85.2617 - r2_keras: 0.5035 - val_loss: 74.4127 - val_r2_keras: 0.5321
# Epoch 18/500
#  - 3s - loss: 82.0418 - r2_keras: 0.5234 - val_loss: 72.8024 - val_r2_keras: 0.5420
# Epoch 19/500
#  - 3s - loss: 79.0632 - r2_keras: 0.5162 - val_loss: 73.0803 - val_r2_keras: 0.5396
# Epoch 20/500
#  - 3s - loss: 77.5485 - r2_keras: 0.5482 - val_loss: 70.3660 - val_r2_keras: 0.5593
# Epoch 21/500
#  - 3s - loss: 75.0958 - r2_keras: 0.5640 - val_loss: 69.0761 - val_r2_keras: 0.5681
# Epoch 22/500
#  - 3s - loss: 73.7186 - r2_keras: 0.5639 - val_loss: 67.9557 - val_r2_keras: 0.5755
# Epoch 23/500
#  - 3s - loss: 70.0968 - r2_keras: 0.5842 - val_loss: 68.5834 - val_r2_keras: 0.5724
# Epoch 24/500
#  - 3s - loss: 69.0677 - r2_keras: 0.5996 - val_loss: 67.2812 - val_r2_keras: 0.5807
# Epoch 25/500
#  - 3s - loss: 68.1068 - r2_keras: 0.6071 - val_loss: 68.9080 - val_r2_keras: 0.5675
# Epoch 26/500
#  - 3s - loss: 68.1351 - r2_keras: 0.5912 - val_loss: 67.6149 - val_r2_keras: 0.5750
# Epoch 27/500
#  - 3s - loss: 68.5850 - r2_keras: 0.5931 - val_loss: 68.3388 - val_r2_keras: 0.5709
# Epoch 28/500
#  - 3s - loss: 66.2241 - r2_keras: 0.6100 - val_loss: 66.8544 - val_r2_keras: 0.5804
# Epoch 29/500
#  - 3s - loss: 68.8495 - r2_keras: 0.6021 - val_loss: 65.8873 - val_r2_keras: 0.5869
# Epoch 30/500
#  - 4s - loss: 66.5665 - r2_keras: 0.6006 - val_loss: 70.4150 - val_r2_keras: 0.5537
# Epoch 31/500
#  - 4s - loss: 65.7513 - r2_keras: 0.6060 - val_loss: 66.8462 - val_r2_keras: 0.5818
# Epoch 32/500
#  - 3s - loss: 64.2004 - r2_keras: 0.6163 - val_loss: 67.6268 - val_r2_keras: 0.5766
# Epoch 33/500
#  - 3s - loss: 64.3691 - r2_keras: 0.6082 - val_loss: 66.5056 - val_r2_keras: 0.5842
# Epoch 34/500
#  - 3s - loss: 62.9284 - r2_keras: 0.6358 - val_loss: 70.0354 - val_r2_keras: 0.5582
# Epoch 35/500
#  - 3s - loss: 60.5497 - r2_keras: 0.6492 - val_loss: 66.3939 - val_r2_keras: 0.5832
# Epoch 36/500
#  - 3s - loss: 64.0296 - r2_keras: 0.6283 - val_loss: 66.0587 - val_r2_keras: 0.5831
# Epoch 37/500
#  - 3s - loss: 61.6962 - r2_keras: 0.6402 - val_loss: 67.5108 - val_r2_keras: 0.5787
# Epoch 38/500
#  - 3s - loss: 62.9520 - r2_keras: 0.6175 - val_loss: 66.5471 - val_r2_keras: 0.5857
# Epoch 39/500
#  - 3s - loss: 61.6968 - r2_keras: 0.6254 - val_loss: 65.5193 - val_r2_keras: 0.5915
# Epoch 40/500
#  - 3s - loss: 59.9736 - r2_keras: 0.6474 - val_loss: 67.9196 - val_r2_keras: 0.5719
# Epoch 41/500
#  - 3s - loss: 59.9371 - r2_keras: 0.6495 - val_loss: 66.5829 - val_r2_keras: 0.5813
# Epoch 42/500
#  - 3s - loss: 59.2472 - r2_keras: 0.6537 - val_loss: 67.5031 - val_r2_keras: 0.5610
# Epoch 43/500
#  - 3s - loss: 59.6468 - r2_keras: 0.6464 - val_loss: 67.0808 - val_r2_keras: 0.5770
# Epoch 44/500
#  - 3s - loss: 58.1456 - r2_keras: 0.6586 - val_loss: 67.1332 - val_r2_keras: 0.5798
# Epoch 45/500
#  - 3s - loss: 60.7471 - r2_keras: 0.6431 - val_loss: 69.1795 - val_r2_keras: 0.5655
# Epoch 46/500
#  - 3s - loss: 58.4479 - r2_keras: 0.6319 - val_loss: 67.3915 - val_r2_keras: 0.5708
# Epoch 47/500
#  - 3s - loss: 56.6597 - r2_keras: 0.6677 - val_loss: 66.5506 - val_r2_keras: 0.5831
# Epoch 48/500
#  - 3s - loss: 56.7292 - r2_keras: 0.6679 - val_loss: 67.5635 - val_r2_keras: 0.5766
# Epoch 49/500
#  - 3s - loss: 56.6791 - r2_keras: 0.6552 - val_loss: 69.3729 - val_r2_keras: 0.5642
# Epoch 50/500
#  - 3s - loss: 57.7020 - r2_keras: 0.6654 - val_loss: 71.1248 - val_r2_keras: 0.5454
# Epoch 51/500
#  - 3s - loss: 56.0460 - r2_keras: 0.6794 - val_loss: 69.0059 - val_r2_keras: 0.5677
# Epoch 52/500
#  - 3s - loss: 56.6035 - r2_keras: 0.6689 - val_loss: 76.1192 - val_r2_keras: 0.4786
# Epoch 53/500
#  - 3s - loss: 58.2339 - r2_keras: 0.6603 - val_loss: 68.8510 - val_r2_keras: 0.5619
# Epoch 54/500
#  - 3s - loss: 55.6913 - r2_keras: 0.6636 - val_loss: 68.7733 - val_r2_keras: 0.5671
# Epoch 55/500
#  - 3s - loss: 54.2638 - r2_keras: 0.6821 - val_loss: 68.5534 - val_r2_keras: 0.5730
# Epoch 56/500
#  - 3s - loss: 52.6304 - r2_keras: 0.6973 - val_loss: 71.5323 - val_r2_keras: 0.5156
# Epoch 57/500
#  - 3s - loss: 56.5201 - r2_keras: 0.6647 - val_loss: 71.3564 - val_r2_keras: 0.5271
# Epoch 58/500
#  - 3s - loss: 54.0250 - r2_keras: 0.6791 - val_loss: 68.4533 - val_r2_keras: 0.5664
# Epoch 59/500
#  - 3s - loss: 51.9527 - r2_keras: 0.6850 - val_loss: 81.1905 - val_r2_keras: 0.4619
# Epoch 00059: early stopping
# dict_keys(['val_loss', 'val_r2_keras', 'loss', 'r2_keras'])
# MSE train: 7.505138129737535
# R^2 train: 0.6522958036867669
# MSE val: 8.094402280750305
# R^2 val: 0.5790595972457561
# [ 78.22526   95.21174   78.338104 ...  91.94413  112.38416   91.89599 ]
